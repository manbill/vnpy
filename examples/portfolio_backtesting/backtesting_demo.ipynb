# %%
from datetime import datetime
from importlib import reload

import vnpy_portfoliostrategy
reload(vnpy_portfoliostrategy)

from vnpy_portfoliostrategy import BacktestingEngine
from vnpy.trader.constant import Interval
from vnpy.trader.optimize import OptimizationSetting

import vnpy_portfoliostrategy.strategies.pair_trading_strategy as stg
reload(stg)
from vnpy_portfoliostrategy.strategies.pair_trading_strategy import PairTradingStrategy

# %%
engine = BacktestingEngine()
engine.set_parameters(
    vt_symbols=["y888.DCE", "p888.DCE"],
    interval=Interval.MINUTE,
    start=datetime(2019, 1, 1),
    end=datetime(2020, 4, 30),
    rates={
        "y888.DCE": 0/10000,
        "p888.DCE": 0/10000
    },
    slippages={
        "y888.DCE": 0,
        "p888.DCE": 0
    },
    sizes={
        "y888.DCE": 10,
        "p888.DCE": 10
    },
    priceticks={
        "y888.DCE": 1,
        "p888.DCE": 1
    },
    capital=1_000_000,
)

setting = {
    "boll_window": 20,
    "boll_dev": 1,
}
engine.add_strategy(PairTradingStrategy, setting)

# %%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# 2024-12-07 03:47:03.997799	开始加载历史数据
# 2024-12-07 03:47:04.040462	y888.DCE加载进度： [6%]
# 2024-12-07 03:47:04.041443	y888.DCE加载进度：# [12%]
# 2024-12-07 03:47:04.042456	y888.DCE加载进度：# [19%]
# 2024-12-07 03:47:04.043443	y888.DCE加载进度：## [25%]
# 2024-12-07 03:47:04.045507	y888.DCE加载进度：### [31%]
# 2024-12-07 03:47:04.046448	y888.DCE加载进度：### [37%]
# 2024-12-07 03:47:04.047443	y888.DCE加载进度：#### [43%]
# 2024-12-07 03:47:04.048477	y888.DCE加载进度：#### [49%]
# 2024-12-07 03:47:04.049444	y888.DCE加载进度：##### [56%]
# 2024-12-07 03:47:04.050483	y888.DCE加载进度：###### [62%]
# 2024-12-07 03:47:04.051478	y888.DCE加载进度：###### [68%]
# 2024-12-07 03:47:04.052478	y888.DCE加载进度：####### [74%]
# 2024-12-07 03:47:04.053486	y888.DCE加载进度：######## [80%]
# 2024-12-07 03:47:04.055481	y888.DCE加载进度：######## [87%]
# 2024-12-07 03:47:04.056478	y888.DCE加载进度：######### [93%]
# 2024-12-07 03:47:04.057476	y888.DCE加载进度：######### [99%]
# 2024-12-07 03:47:04.058478	y888.DCE加载进度：########## [100%]
# 2024-12-07 03:47:04.058478	y888.DCE历史数据加载完成，数据量：0
# 2024-12-07 03:47:04.059480	p888.DCE加载进度： [6%]
# 2024-12-07 03:47:04.060479	p888.DCE加载进度：# [12%]
# 2024-12-07 03:47:04.061480	p888.DCE加载进度：# [19%]
# 2024-12-07 03:47:04.062478	p888.DCE加载进度：## [25%]
# 2024-12-07 03:47:04.063446	p888.DCE加载进度：### [31%]
# 2024-12-07 03:47:04.064447	p888.DCE加载进度：### [37%]
# 2024-12-07 03:47:04.065478	p888.DCE加载进度：#### [43%]
# 2024-12-07 03:47:04.067475	p888.DCE加载进度：#### [49%]
# %%
setting = OptimizationSetting()
setting.set_target("sharpe_ratio")
setting.add_parameter("boll_window", 10, 30, 1)
setting.add_parameter("boll_dev", 1, 3, 1)

engine.run_ga_optimization(setting)
# Out:
# 2024-12-07 03:47:10.933601	开始执行遗传算法优化
# 2024-12-07 03:47:10.934600	参数优化空间：63
# 2024-12-07 03:47:10.934600	每代族群总数：100
# 2024-12-07 03:47:10.934600	优良筛选个数：80
# 2024-12-07 03:47:10.934600	迭代次数：30
# 2024-12-07 03:47:10.934600	交叉概率：95%
# 2024-12-07 03:47:10.934600	突变概率：5%
# gen	nevals
# 0  	100
# 1  	100
# 2  	100
# 3  	100
# 4  	100
# 5  	100
# 6  	100
# 7  	100
# 8  	100
# 9  	100
# 10 	100
# 11 	100
# 12 	100
# 13 	100
# 14 	100
# 15 	100
# 16 	100
# 17 	100
# 18 	100
# 19 	100
# 20 	100
# 21 	100
# 22 	100
# 23 	100
# 24 	100
# 25 	100
# 26 	100
# 27 	100
# 28 	100
# 29 	100
# 30 	100
# 2024-12-07 03:47:23.086944	遗传算法优化完成，耗时12秒
# 2024-12-07 03:47:23.359959	参数：{'boll_window': 21, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.360489	参数：{'boll_window': 22, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.360489	参数：{'boll_window': 14, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.360489	参数：{'boll_window': 11, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.360489	参数：{'boll_window': 27, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.360489	参数：{'boll_window': 24, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.360489	参数：{'boll_window': 10, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.360489	参数：{'boll_window': 21, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.360489	参数：{'boll_window': 17, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.360489	参数：{'boll_window': 27, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.360489	参数：{'boll_window': 10, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.360489	参数：{'boll_window': 25, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.360489	参数：{'boll_window': 15, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.360489	参数：{'boll_window': 13, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 16, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 24, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 26, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 20, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 19, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 28, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 10, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 20, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 11, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 12, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 28, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 18, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 22, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 12, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 12, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 18, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 25, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 21, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 29, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 22, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 15, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 15, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 17, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 29, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 17, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 14, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 23, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 24, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 18, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 29, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 23, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 16, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 30, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 13, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 11, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 19, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 20, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 16, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 13, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 28, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 14, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 30, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 19, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 26, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 25, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 26, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 27, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:23.361020	参数：{'boll_window': 23, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:23.361550	参数：{'boll_window': 30, 'boll_dev': 3}, 目标：0
# [("{'boll_window': 21, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 22, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 14, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 11, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 27, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 24, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 10, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 21, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 17, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 27, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 10, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 25, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 15, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 13, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 16, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 24, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 26, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 20, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 19, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 28, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 10, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 20, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 11, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 12, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 28, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 18, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 22, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 12, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 12, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 18, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 25, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 21, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 29, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 22, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 15, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 15, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 17, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 29, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 17, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 14, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 23, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 24, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 18, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 29, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 23, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 16, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 30, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 13, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 11, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 19, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 20, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 16, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 13, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 28, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 14, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 30, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 19, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 26, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 25, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 26, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 27, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 23, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 30, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0})]

# %%
engine.run_bf_optimization(setting)
# Out:
# 2024-12-07 03:47:23.438540	开始执行穷举算法优化
# 2024-12-07 03:47:23.438540	参数优化空间：63
# 100%|██████████| 63/63 [00:02<00:00, 21.83it/s]
# 2024-12-07 03:47:27.459582	穷举算法优化完成，耗时4秒
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 10, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 10, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 10, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 11, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 11, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 11, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 12, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 12, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 12, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 13, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 13, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 13, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 14, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 14, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 14, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 15, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 15, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 15, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 16, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 16, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 16, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 17, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 17, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 17, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 18, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 18, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 18, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 19, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 19, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 19, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 20, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 20, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 20, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 21, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 21, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 21, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 22, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 22, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 22, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.974184	参数：{'boll_window': 23, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 23, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 23, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 24, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 24, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 24, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 25, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 25, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 25, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 26, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 26, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 26, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 27, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 27, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 27, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 28, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 28, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 28, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 29, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 29, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 29, 'boll_dev': 3}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 30, 'boll_dev': 1}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 30, 'boll_dev': 2}, 目标：0
# 2024-12-07 03:47:27.975693	参数：{'boll_window': 30, 'boll_dev': 3}, 目标：0
# [("{'boll_window': 10, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 10, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 10, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 11, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 11, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 11, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 12, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 12, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 12, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 13, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 13, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 13, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 14, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 14, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 14, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 15, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 15, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 15, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 16, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 16, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 16, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 17, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 17, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 17, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 18, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 18, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 18, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 19, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 19, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 19, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 20, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 20, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 20, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 21, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 21, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 21, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 22, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 22, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 22, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 23, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 23, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 23, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 24, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 24, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 24, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 25, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 25, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 25, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 26, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 26, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 26, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 27, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 27, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 27, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 28, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 28, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 28, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 29, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 29, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 29, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 30, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 30, 'boll_dev': 2}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 30, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0})]
